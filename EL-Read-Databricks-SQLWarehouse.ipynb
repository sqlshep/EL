# %%
# %pip install databricks
# %pip install databricks-sql-connector

# %%
from databricks import sql

import pandas as pd
import os

connection = sql.connect(
                        server_hostname = "xxx",
                        http_path = "xxx",
                        access_token = "xxx")

cursor = connection.cursor()

cursor.execute("select * from flight_delta.FlightDeltaLake limit 10 ")



result = cursor.fetchall()

type(result)

#print(result)

df = pd.DataFrame(data=result)
                  
df = pd.DataFrame(data=result, columns = ['Year','Month','DayofMonth','DayOfWeek','DepTime','CRSDepTime','ArrTime','CRSArrTime','UniqueCarrier','FlightNum','TailNum','ActualElapsedTime','CRSElapsedTime','AirTime','ArrDelay','DepDelay','Origin','Dest','Distance','TaxiIn','TaxiOut','Cancelled','CancellationCode','Diverted','CarrierDelay','WeatherDelay','NASDelay','SecurityDelay','LateAircraftDelay','IsArrDelayed','IsDepDelayed'])

cursor.close()
connection.close()

# %%
df
# Out:
#    Year  Month  DayofMonth  DayOfWeek DepTime  CRSDepTime ArrTime  CRSArrTime  \
# 0  1987     10          14          3     741         730     912         849
# 1  1987     10          15          4     729         730     903         849
# 2  1987     10          17          6     741         730     918         849
# 3  1987     10          18          7     729         730     847         849
# 4  1987     10          19          1     749         730     922         849
# 5  1987     10          21          3     728         730     848         849
# 6  1987     10          22          4     728         730     852         849
# 7  1987     10          23          5     731         730     902         849
# 8  1987     10          24          6     744         730     908         849
# 9  1987     10          25          7     729         730     851         849
#
#   UniqueCarrier  FlightNum  ... Cancelled CancellationCode  Diverted  \
# 0            PS       1451  ...         0               NA         0
# 1            PS       1451  ...         0               NA         0
# 2            PS       1451  ...         0               NA         0
# 3            PS       1451  ...         0               NA         0
# 4            PS       1451  ...         0               NA         0
# 5            PS       1451  ...         0               NA         0
# 6            PS       1451  ...         0               NA         0
# 7            PS       1451  ...         0               NA         0
# 8            PS       1451  ...         0               NA         0
# 9            PS       1451  ...         0               NA         0
#
#   CarrierDelay WeatherDelay NASDelay SecurityDelay LateAircraftDelay  \
# 0           NA           NA       NA            NA                NA
# 1           NA           NA       NA            NA                NA
# 2           NA           NA       NA            NA                NA
# 3           NA           NA       NA            NA                NA
# 4           NA           NA       NA            NA                NA
# 5           NA           NA       NA            NA                NA
# 6           NA           NA       NA            NA                NA
# 7           NA           NA       NA            NA                NA
# 8           NA           NA       NA            NA                NA
# 9           NA           NA       NA            NA                NA
#
#   IsArrDelayed IsDepDelayed
# 0          YES          YES
# 1          YES           NO
# 2          YES          YES
# 3           NO           NO
# 4          YES          YES
# 5           NO           NO
# 6          YES           NO
# 7          YES          YES
# 8          YES          YES
# 9          YES           NO
#
# [10 rows x 31 columns]
